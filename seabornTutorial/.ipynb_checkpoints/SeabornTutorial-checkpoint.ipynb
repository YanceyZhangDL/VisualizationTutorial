# %% [markdown]
# ### Documents

# %% [markdown]
# 官方教程：http://seaborn.pydata.org/introduction.html

# %% [markdown]
# ### Init

# %%
import seaborn as sns

# %%
# We apply the default default seaborn theme, scaling, and color palette.
# other themes: http://seaborn.pydata.org/tutorial/aesthetics.html#aesthetics-tutorial
# seaborn 默认背景设置
sns.set()

# %%
'''
Most code in the docs will use the load_dataset() function to get quick access to an example dataset. 
There’s nothing particularly special about these datasets; 
they are just pandas dataframes, and we could have loaded them with pandas.read_csv() or build them by hand. 
'''
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
'''
This particular plot shows the relationship between five variables in the tips dataset. 
Three are numeric, and two are categorical. 
Two numeric variables (total_bill and tip) determined the position of each point on the axes, 
and the third (size) determined the size of each point. 
One categorical variable split the dataset onto two different axes (facets), 
and the other determined the color and shape of each point.

All of this was accomplished using a single call to the seaborn function relplot()
'''
# Q: 格式只能用列的值来指定？
sns.relplot(x="total_bill", y="tip", 
            col="time", # 根据col划分成多个图
            hue="smoker", # color
            style="smoker", # shape
            size="size", # size of each point
            data=tips # dataframe
           )

# %% [markdown]
# ### Different kinds of visualization

# %%
dots = sns.load_dataset("dots")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
# or kind="scatter"
'''
这三个同时作用才产生了多条线
hue="choice", 
size="coherence", 
style="choice",
'''
sns.relplot(x="time", y="firing_rate", col="align", # 分类目来画图
            hue="choice", 
            size="coherence", 
            style="choice",
            facet_kws=dict(sharex=False), #  将坐标轴拉伸到合适的位置
            kind="line", # 默认是散点图，这个指定为划线
            legend="full", # 右侧图例显示最原始的标记
            data=dots)

# %%
# or kind="scatter"
sns.relplot(x="time", y="firing_rate", col="align", # 分类目来画图
            hue="choice", size="coherence", style="choice",
            facet_kws=dict(sharex=False), #  将坐标轴拉伸到合适的位置
            kind="line", # 默认是散点图，这个指定为划线
            #legend="full", 
            data=dots)

# %% [markdown]
# ### Statistical estimation and error bars

# %%
fmri = sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
'''
Often we are interested in the average value of one variable as a function of other variables. 
Many seaborn functions can automatically perform the statistical estimation that is necessary to answer these questions:
'''
# 因为这里横坐标的每个点有个上下限的范围
# 所以这里除了画出上下限，还自动画了个均线
sns.relplot(x="timepoint", y="signal", col="region",
            hue="event", style="event",
            kind="line", 
            data=fmri)

# %%
'''
Statistical estimation in seaborn goes beyond descriptive statistics. 
For example, 
it is also possible to enhance a scatterplot to include a linear regression model (and its uncertainty)
using lmplot():
'''
sns.lmplot(x="total_bill", y="tip", col="time", 
           hue="smoker", # color
           data=tips);

# %% [markdown]
# ### Specialized categorical plots

# %% [markdown]
# many data analyses involve <font color=red>categorical variables</font>.
# There are several specialized plot types in seaborn that are optimized for visualizing this kind of data.
# They can be accessed through <font color=red>catplot()</font>.

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="swarm", data=tips);

# %% [markdown]
# Alternately, you could use kernel density estimation(核密度估计) to represent the underlying distribution that the points are sampled from:

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="violin", split=True, data=tips);

# %% [markdown]
# Or you could show the only mean value and its confidence interval(置信区间) within each nested category:

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            kind="bar", data=tips);

# %% [markdown]
# ### Figure-level and axes-level functions

# %% [markdown]
# The way you can tell whether a function is “figure-level” or “axes-level” is whether it takes an ax= parameter.
#
# You can also distinguish the two classes by their output type:
# 1. axes-level functions return the matplotlib axes,
# 2. while figure-level functions return the FacetGrid.

# %%
import matplotlib.pyplot as plt
f, axes = plt.subplots(1, 2, sharey=True, figsize=(6, 4))

sns.boxplot(x="day", y="tip", data=tips, ax=axes[0])
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips, ax=axes[1])

# %% [markdown]
# ### Visualizing dataset structure

# %% [markdown]
# There are two other kinds of figure-level functions in seaborn that can be used to make visualizations with multiple plots.
#
# They are each oriented towards illuminating the structure of a dataset.
# 1. One, jointplot(), focuses on a single relationship:

# %%
iris = sns.load_dataset("iris")

# %%
sns.jointplot(x="sepal_length", y="petal_length", data=iris);

# %% [markdown]
# The other, pairplot(), takes a broader view, <font color=red>showing all pairwise relationships and the marginal distributions</font>, optionally conditioned on a categorical variable :

# %%
sns.pairplot(data=iris, hue="species")

# %% [markdown]
# ### Customizing plot appearance

# %% [markdown]
# Some customization of figure-level functions can be accomplished <font color=red>through additional parameters that get passed to FacetGrid</font>, and you can use the methods on that object to control many other properties of the figure.
#
# For even more tweaking, you can access the matplotlib objects that the plot is drawn onto, which are stored as attributes:

# %%
g = sns.catplot(x="total_bill", y="day", hue="time",
                height=3.5, aspect=1.5,
                kind="box", 
                legend=False, data=tips);
g.add_legend(title="Meal")
g.set_axis_labels("Total bill ($)", "")
g.set(xlim=(0, 60), yticklabels=["Thursday", "Friday", "Saturday", "Sunday"])
g.despine(trim=True)
g.fig.set_size_inches(6.5, 3.5)
g.ax.set_xticks([5, 15, 25, 35, 45, 55], minor=True);
plt.setp(g.ax.get_yticklabels(), rotation=30);

# %% [markdown]
# ### Organizing datasets

# %% [markdown]
# 简而言之，就是说，你怎么把数据整理成合适的适合Seaborn的figure模式处理的形式？？？

# %% [markdown]
# The rules can be simply stated:
# 1. Each variable is a column
# 2. Each observation is a row

# %% [markdown]
# 参考文章: https://tomaugspurger.github.io/modern-5-tidy.html

# %% [markdown]
# pandas.melt:
# 0. 文档：https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html#pandas-melt
# 1. 可以理解为把哪些列生成到新的列里面
# 2. 或者将多列的列名[value_vars]合并生成新的一列，对应的值单独生成一个value列！！！

# %%
# Example
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})
print (df)
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6
